# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, explode, explode_outer
from pyspark.sql import functions as F

# %%
# creation d'une session spark 
spark = SparkSession.builder \
    .appName("Traitement_depuis_hdfs") \
    .master("yarn") \
    .config("spark.hadoop.fs.defaultFS", "hdfs://namenode:8020") \
    .config("spark.hadoop.yarn.resourcemanager.hostname", "resourcemanager") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/09 12:34:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/12/09 12:34:23 WARN Client: Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.

# %%
spark.version
# Out:
# '3.5.7'

# %%
# lecture de nos fichier hdfs 
df = spark.read.option("mergeSchema", "true").parquet("hdfs://namenode:8020/ben/dataLake/")

# %%
df.show(5)
# Out:
# +-----------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+----+----------------+
# | entreprise|               poste|niveau_etude|   niveau_experience|     contrat_propose|              region|          Competence|date_de_publication|           formation|lien|contract_propose|
# +-----------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+----+----------------+
# |AFRICASHORE|AWS Cloud Archite...|       Bac+3|Expérience entre ...|CDI, CDD - Freelance|Dakar - Diourbel ...|AGILE - ALM - BAS...|         04.06.2025|<li><strong>Bache...|NULL|            NULL|
# |AFRICASHORE|UX / UI Designer ...|       Bac+3|Expérience entre ...|CDI, CDD - Freelance|Dakar - Diourbel ...|AJAX - BOOTSTRAP ...|         04.06.2025|<li><strong>Bache...|NULL|            NULL|
# |AFRICASHORE|Test Automation E...|       Bac+3|Expérience entre ...|CDI, CDD - Freelance|Dakar - Diourbel ...|API - CVS - GIT -...|         04.06.2025|<li><strong>Bache...|NULL|            NULL|
# |AFRICASHORE|Test and Validati...|       Bac+3|Expérience entre ...|CDI, CDD - Freelance|Dakar - Diourbel ...|   CVS - RHEL - SUSE|         04.06.2025|<li><strong>Bache...|NULL|            NULL|
# |AFRICASHORE|SWIFT Developer (...|       Bac+3|Expérience entre ...|CDI, CDD - Freelance|Dakar - Diourbel ...|AGILE - CVS - GIT...|         04.06.2025|<li><strong>Bache...|NULL|            NULL|
# +-----------+--------------------+------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+----+----------------+
# only showing top 5 rows

# %%
df = df.dropDuplicates()

# %%
# compter les nombres de lignes qu'on a 
df.count()
# Out:
# 404

# %%
# voir le schema ou les differents colonnes de nos données 
df.printSchema()
# Out:
# root
#  |-- entreprise: string (nullable = true)
#  |-- poste: string (nullable = true)
#  |-- niveau_etude: string (nullable = true)
#  |-- niveau_experience: string (nullable = true)
#  |-- contrat_propose: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- Competence: string (nullable = true)
#  |-- date_de_publication: string (nullable = true)
#  |-- formation: string (nullable = true)
#  |-- lien: string (nullable = true)
#  |-- contract_propose: string (nullable = true)

# %%
# Les nombres de differents poste et  entreprises existantes 
df.select("poste").distinct().count()
# Out:
# 389

# %% [markdown]
# ## Colonnes a nettoyer et organiser

# %%
# Apres un passage de select, exemple la colonne suivant '"entreprise"
df.select("entreprise").distinct().show(5, truncate=False)
# Out:
# [Stage 14:=================================================>        (6 + 1) / 7]
# +----------------------------------------+
# |entreprise                              |
# +----------------------------------------+
# |TECTRA SÉNÉGAL                          |
# |MOUABI                                  |
# |VISION PLUS VOYAGE                      |
# |SOCIÉTÉ DE PROMOTION ET DE CONSTRUCTION |
# |NEXGEN TALENT                           |
# +----------------------------------------+
# only showing top 5 rows

# %% [markdown]
# ### traitement de chaque colonne

# %% [markdown]
# #### formation

# %%
# ---------------- pour la colonne formation 

df_formation = df.withColumn(
    "formation_clean",
    F.trim(
        F.regexp_replace(F.col("formation"), r"</li><li>", ", "))
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.regexp_replace(F.col("formation_clean"), r"</?li>", "")
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.regexp_replace(F.col("formation_clean"), r"[\n]", "")
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.regexp_replace(F.col("formation_clean"),r"</?strong>", "")
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.trim(F.regexp_replace(F.col("formation_clean"), r"<[^>]+>", ""))
)

df_formation.drop("formation")
# Out:
# DataFrame[entreprise: string, poste: string, niveau_etude: string, niveau_experience: string, contrat_propose: string, region: string, Competence: string, date_de_publication: string, lien: string, contract_propose: string, formation_clean: string]

# %% [markdown]
# #### niveau etude

# %%
#-------------- Pour la colonne niveau_etude--------------

df_etude = df_formation.withColumn(
    "niveau_etude_clean",
    split(col("niveau_etude"), r"\s*(?:,|&|et)\s*")
)

df_etude = df_etude.drop("niveau_etude")
df_etude = df_etude.drop("formation")

# %% [markdown]
# #### contract proposé

# %%
##------------ contract proposé ---------------------------
df_contract = df_etude.withColumn(
    "contract",
    split(col("contrat_propose"), r"\s*(?:,|&|et)\s*")
)

df_contract = df_contract.drop("contrat_propose")

# %% [markdown]
# #### region

# %%
### ------------- Pour la region 

df_region = df_contract.withColumn(
    "region_clean",
    F.trim(F.regexp_replace(F.col("region"), r"\s*(?:\n|\t)", ""))

)

# %% [markdown]
# #### Experience

# %%
# ----- experience 

df_experience = df_region.withColumn(
    "experience", 
    split(col("niveau_experience"), r"\s*(?:,|&|-)\s*")
)

df_experience = df_experience.drop("niveau_experience")

# %% [markdown]
# #### Competences

# %%
#---------- Traitement des competences 

df_competence = df_experience.withColumn(
    "competences",
    split(col("Competence"), r"\s*(-)\s*")
)

# %%
df_competence.show(3)
# Out:
# [Stage 17:=================================================>        (6 + 1) / 7]
# +----------------+--------------------+--------------------+--------------------+-------------------+----+----------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      entreprise|               poste|              region|          Competence|date_de_publication|lien|contract_propose|     formation_clean|  niveau_etude_clean|          contract|        region_clean|          experience|         competences|
# +----------------+--------------------+--------------------+--------------------+-------------------+----+----------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |INTRA INTERIM SN|Ouvrier d’Usine -...|       International|Accompagnement - ...|         20.06.2025|NULL|            NULL|Niveau d’anglais ...|[Qualification av...|    [CDI, Intérim]|       International|[Etudiant, jeune ...|[Accompagnement, ...|
# |        TALIACOM|   Graphiste - Dakar|Dakar - Thiès & I...|                 CMS|         01.08.2025|NULL|            NULL|Vous acquérez vot...|[Bac+2, Bac+3, Ba...|[Stage, Freelance]|Dakar - Thiès & I...|[Expérience entre...|               [CMS]|
# |  CABINET CARREE|Responsable Admin...|               Dakar|Comptabilité - Co...|         01.07.2025|NULL|            NULL|Formation supérie...|       [Bac+5, plus]|             [CDI]|               Dakar|[Expérience entre...|[Comptabilité, Co...|
# +----------------+--------------------+--------------------+--------------------+-------------------+----+----------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# only showing top 3 rows

# %% [markdown]
# ## Creation de la premiere dataset qui contient toutes les données

# %%
df_clean = df_competence.drop("Competence")
df_clean.show(5, truncate=False)
# Out:
# [Stage 20:=================================================>        (6 + 1) / 7]
# +----------------+-----------------------------------------------------+-----------------------------------------------------------------+-------------------+----+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------+-----------------------------------------------------------------+-----------------------------------------+--------------------------------------------------------------------------------------------------------+
# |entreprise      |poste                                                |region                                                           |date_de_publication|lien|contract_propose|formation_clean                                                                                                              |niveau_etude_clean                                                     |contract              |region_clean                                                     |experience                               |competences                                                                                             |
# +----------------+-----------------------------------------------------+-----------------------------------------------------------------+-------------------+----+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------+-----------------------------------------------------------------+-----------------------------------------+--------------------------------------------------------------------------------------------------------+
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)                  |International                                                    |20.06.2025         |NULL|NULL            |Niveau d’anglais intermédiaire requis                                                                                        |[Qualification avant bac, Bac, Bac+1, Bac+2, Bac+3, Bac+4, Bac+5, plus]|[CDI, Intérim]        |International                                                    |[Etudiant, jeune diplômé et plus]        |[Accompagnement, Assemblage, Emballage, Maintenance, Production, Qualité, Sécurité]                     |
# |TALIACOM        |Graphiste - Dakar                                    |Dakar - Thiès & International                                    |01.08.2025         |NULL|NULL            |Vous acquérez votre licence Kuik.fr à un tarif préférentiel                                                                  |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[Stage, Freelance]    |Dakar - Thiès & International                                    |[Expérience entre 2 ans et 5 ans et plus]|[CMS]                                                                                                   |
# |CABINET CARREE  |Responsable Administratif et Financier Senior - Dakar|Dakar                                                            |01.07.2025         |NULL|NULL            |Formation supérieure en finance, comptabilité, gestion (Bac +5 minimum – type Master CCA, DSCG, MBF, école de commerce, etc.)|[Bac+5, plus]                                                          |[CDI]                 |Dakar                                                            |[Expérience entre 5 ans et 10 ans]       |[Comptabilité, Comptabilité Générale, États Financiers, Finance, Financement, Gestion, IFRS, Trésorerie]|
# |ONE TO ONE      |Expert SEO Confirmé (H/F)  - Télétravail             |International                                                    |07.07.2025         |NULL|NULL            |Minimum 3 ans d’expérience prouvée en SEO (idéalement en agence ou en freelance multi-clients)                               |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[CDI, Freelance]      |International                                                    |[Expérience entre 2 ans et 5 ans et plus]|[Netlinking, Positionnement, Référencement Naturel, Référencement SEO, SEO]                             |
# |AFRICASHORE     |Cloud System Integrator (M/F)                        |Dakar - Diourbel - Fatick - Kaffrine - Kaolack - Kédougou - Kolda|04.06.2025         |NULL|NULL            |Bachelors degree in Cloud Computing or related.                                                                              |[Bac+3]                                                                |[CDI, CDD - Freelance]|Dakar - Diourbel - Fatick - Kaffrine - Kaolack - Kédougou - Kolda|[Expérience entre 5 ans et 10 ans]       |[AGILE, CVS]                                                                                            |
# +----------------+-----------------------------------------------------+-----------------------------------------------------------------+-------------------+----+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------+-----------------------------------------------------------------+-----------------------------------------+--------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
df_clean.select('lien').distinct().show()
# Out:
# [Stage 23:=================================================>        (6 + 1) / 7]
# +--------------------+
# |                lien|
# +--------------------+
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# +--------------------+
# only showing top 20 rows

# %%
df_clean.select('competences').show(truncate= False)
# Out:
# [Stage 26:=================================================>        (6 + 1) / 7]
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |competences                                                                                                                                                                                                                                            |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[Accompagnement, Assemblage, Emballage, Maintenance, Production, Qualité, Sécurité]                                                                                                                                                                    |
# |[CMS]                                                                                                                                                                                                                                                  |
# |[Comptabilité, Comptabilité Générale, États Financiers, Finance, Financement, Gestion, IFRS, Trésorerie]                                                                                                                                               |
# |[Netlinking, Positionnement, Référencement Naturel, Référencement SEO, SEO]                                                                                                                                                                            |
# |[AGILE, CVS]                                                                                                                                                                                                                                           |
# |[3D 2D, 4D, Nettoyage]                                                                                                                                                                                                                                 |
# |[AGILE, ANGULAR JS, AZURE, BIG DATA, CASSANDRA, COUCHBASE, CSS, CVS, DOCKER, GIT, HADOOP, HIBERNATE, HTML, J2EE, JAVA, JAVA JEE, JAVASCRIPT, JBOSS, JENKINS, MAVEN, MVC, MYSQL, NOSQL, ORACLE, REDIS, REST, SOAP, SPARK, SPRING, SQL, STRUTS, WEBLOGIC]|
# |[Gestion, Management, Planification]                                                                                                                                                                                                                   |
# |[Fabrication, Gestion Industrielle, Industrie, Maintenance, Normes de Qualité, Processus, Production, Productivité, Qualité, Techniques de Production]                                                                                                 |
# |[Amélioration Continue, Fluide, Maintenance, Production, Productivité, Qualité]                                                                                                                                                                        |
# |[Architecture d'Intérieur, Construction, Décoration]                                                                                                                                                                                                   |
# |[REACH, SAP]                                                                                                                                                                                                                                           |
# |NULL                                                                                                                                                                                                                                                   |
# |[Comptabilité, Encours Clients, Facturation, Finance, Gestion, Recouvrement]                                                                                                                                                                           |
# |[AGILE, CVS, GIT, MERCURIAL, REST, SCRUM, SWIFT]                                                                                                                                                                                                       |
# |[Assistanat, Secrétariat, Transport]                                                                                                                                                                                                                   |
# |[AZURE, CENTOS, CVS, DOCKER, LINUX, PERL, PREMISE, PYTHON, REDHAT, VPN, WAN]                                                                                                                                                                           |
# |[Vente]                                                                                                                                                                                                                                                |
# |[AGILE, API, APP, CVS, JAVA, MAVEN, MYSQL, SCRUM, SELENIUM, SQL]                                                                                                                                                                                       |
# |[Communication, Marketing, Vente]                                                                                                                                                                                                                      |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## Creation du deuxieme dataset pour le machine learning

# %%
df_clean.select("entreprise","poste","lien").distinct().show(3, truncate=False
                                            )
# Out:
# [Stage 29:=================================================>        (6 + 1) / 7]
# +---------------------------+--------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |entreprise                 |poste                           |lien                                                                                                                                                        |
# +---------------------------+--------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Sunda International        |Assistant RH                    |https://www.emploidakar.com/offre-demploi/sunda-international-dakar-cdd-assistant-rh/                                                                       |
# |Elite RH                   |Commerciaux                     |https://www.emploidakar.com/offre-demploi/elite-rh-thies-mbour-kaolack-prestation-de-services-commerciaux/                                                  |
# |Phoenix Consulting Group SN|Assistant Administratif Bilingue|https://www.emploidakar.com/offre-demploi/phoenix-consulting-group-sn-dakar-cdd-phoenix-consulting-group-africa-senegal-recherche-un-assistant-bilingue-h-f/|
# +---------------------------+--------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 3 rows

# %%
tab = df_clean.select("entreprise", "poste", 'lien',explode_outer(col("competences")).alias("competence"))

# %%
df_filter = tab.filter(col("entreprise").like("%Sama %"))
    #select('poste', 'competence', 'lien').distinct().show()

df_filter.select('poste','competence', 'lien').distinct().show()
# Out:
# [Stage 48:=================================================>        (6 + 1) / 7]
# +--------------------+----------+--------------------+
# |               poste|competence|                lien|
# +--------------------+----------+--------------------+
# |03 Coordonnateurs...|      NULL|https://www.emplo...|
# |20 Agents Call Ce...|      NULL|https://www.emplo...|
# |   Agents Formateurs|      NULL|https://www.emplo...|
# |Superviseur Admin...|      NULL|https://www.emplo...|
# +--------------------+----------+--------------------+

# %%
tab.filter(col("entreprise").like("%Sama%")).show()
# Out:
# [Stage 54:=================================================>        (6 + 1) / 7]
# +------------------+--------------------+--------------------+----------+
# |        entreprise|               poste|                lien|competence|
# +------------------+--------------------+--------------------+----------+
# |Sama Mbey (myAgro)|   Agents Formateurs|https://www.emplo...|      NULL|
# |Sama Mbey (myAgro)|Superviseur Admin...|https://www.emplo...|      NULL|
# |Sama Mbey (myAgro)|20 Agents Call Ce...|https://www.emplo...|      NULL|
# |Sama Mbey (myAgro)|03 Coordonnateurs...|https://www.emplo...|      NULL|
# +------------------+--------------------+--------------------+----------+

# %%
df_ml = df_clean.select("entreprise", "poste","lien", explode_outer(col("competences")).alias("competence"),
col("formation_clean").alias("formation"), explode_outer(col("niveau_etude_clean")).alias("niveau_etude"),
explode_outer(col("contract")).alias("contrat"), explode_outer(col("experience")).alias("experience"),
col("region_clean").alias("region"), col("date_de_publication").alias("date_de_pulication")
)

# %%
df_ml.show(5, truncate=False)
# Out:
# [Stage 126:================================================>        (6 + 1) / 7]
# +----------------+-----------------------------------+----+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+------------------+
# |entreprise      |poste                              |lien|competence    |formation                            |niveau_etude           |contrat|experience           |region       |date_de_pulication|
# +----------------+-----------------------------------+----+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+------------------+
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|CDI    |Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|CDI    |jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|Intérim|Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|Intérim|jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |CDI    |Etudiant             |International|20.06.2025        |
# +----------------+-----------------------------------+----+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+------------------+
# only showing top 5 rows

# %%
df_ml.select('lien').distinct().show()
# Out:
# [Stage 129:================================================>        (6 + 1) / 7]
# +--------------------+
# |                lien|
# +--------------------+
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# |https://www.emplo...|
# +--------------------+
# only showing top 20 rows

# %%
df_ml.count()
# Out:
# 7056

# %% [markdown]
# # Nos datasetes

# %% [markdown]
# ## pour le ml

# %%
print("dataset pour le machine learning et l'analyse analytique")
df_ml.show(10, truncate=False)
# Out:
# dataset pour le machine learning et l'analyse analytique
# [Stage 141:================================================>        (6 + 1) / 7]
# +----------------+-----------------------------------+----+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+------------------+
# |entreprise      |poste                              |lien|competence    |formation                            |niveau_etude           |contrat|experience           |region       |date_de_pulication|
# +----------------+-----------------------------------+----+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+------------------+
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|CDI    |Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|CDI    |jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|Intérim|Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|Intérim|jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |CDI    |Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |CDI    |jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |Intérim|Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |Intérim|jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+1                  |CDI    |Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+1                  |CDI    |jeune diplômé et plus|International|20.06.2025        |
# +----------------+-----------------------------------+----+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ## Donnees brutes

# %%
print("dataset normale sur les offres")
df_clean.show(10, truncate=False)
# Out:
# dataset normale sur les offres
# [Stage 144:========================================>                (5 + 2) / 7]
# +----------------------+-----------------------------------------------------+-----------------------------------------------------------------+-------------------+----+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------------------------------------------------------------+-----------------------------------------------------------------+-----------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |entreprise            |poste                                                |region                                                           |date_de_publication|lien|contract_propose|formation_clean                                                                                                              |niveau_etude_clean                                                     |contract                                                                    |region_clean                                                     |experience                               |competences                                                                                                                                                                                                                                            |
# +----------------------+-----------------------------------------------------+-----------------------------------------------------------------+-------------------+----+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------------------------------------------------------------+-----------------------------------------------------------------+-----------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |INTRA INTERIM SN      |Ouvrier d’Usine - Roumanie (Europe)                  |International                                                    |20.06.2025         |NULL|NULL            |Niveau d’anglais intermédiaire requis                                                                                        |[Qualification avant bac, Bac, Bac+1, Bac+2, Bac+3, Bac+4, Bac+5, plus]|[CDI, Intérim]                                                              |International                                                    |[Etudiant, jeune diplômé et plus]        |[Accompagnement, Assemblage, Emballage, Maintenance, Production, Qualité, Sécurité]                                                                                                                                                                    |
# |TALIACOM              |Graphiste - Dakar                                    |Dakar - Thiès & International                                    |01.08.2025         |NULL|NULL            |Vous acquérez votre licence Kuik.fr à un tarif préférentiel                                                                  |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[Stage, Freelance]                                                          |Dakar - Thiès & International                                    |[Expérience entre 2 ans et 5 ans et plus]|[CMS]                                                                                                                                                                                                                                                  |
# |CABINET CARREE        |Responsable Administratif et Financier Senior - Dakar|Dakar                                                            |01.07.2025         |NULL|NULL            |Formation supérieure en finance, comptabilité, gestion (Bac +5 minimum – type Master CCA, DSCG, MBF, école de commerce, etc.)|[Bac+5, plus]                                                          |[CDI]                                                                       |Dakar                                                            |[Expérience entre 5 ans et 10 ans]       |[Comptabilité, Comptabilité Générale, États Financiers, Finance, Financement, Gestion, IFRS, Trésorerie]                                                                                                                                               |
# |ONE TO ONE            |Expert SEO Confirmé (H/F)  - Télétravail             |International                                                    |07.07.2025         |NULL|NULL            |Minimum 3 ans d’expérience prouvée en SEO (idéalement en agence ou en freelance multi-clients)                               |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[CDI, Freelance]                                                            |International                                                    |[Expérience entre 2 ans et 5 ans et plus]|[Netlinking, Positionnement, Référencement Naturel, Référencement SEO, SEO]                                                                                                                                                                            |
# |AFRICASHORE           |Cloud System Integrator (M/F)                        |Dakar - Diourbel - Fatick - Kaffrine - Kaolack - Kédougou - Kolda|04.06.2025         |NULL|NULL            |Bachelors degree in Cloud Computing or related.                                                                              |[Bac+3]                                                                |[CDI, CDD - Freelance]                                                      |Dakar - Diourbel - Fatick - Kaffrine - Kaolack - Kédougou - Kolda|[Expérience entre 5 ans et 10 ans]       |[AGILE, CVS]                                                                                                                                                                                                                                           |
# |REGARD GLOBAL SERVICES|Stagiaire en Qualité de Technicien de Surface - Dakar|Dakar                                                            |16.06.2025         |NULL|NULL            |Minimum niveau BFEM                                                                                                          |[Qualification avant bac, Bac, Bac+1, Bac+2, Bac+3, Bac+4, Bac+5, plus]|[Stage]                                                                     |Dakar                                                            |[Etudiant, jeune diplômé et plus]        |[3D 2D, 4D, Nettoyage]                                                                                                                                                                                                                                 |
# |AFRICASHORE           |JAVA JEE Developer (M/F)                             |Dakar - Diourbel - Fatick - Kaffrine - Kaolack - Kédougou - Kolda|04.06.2025         |NULL|NULL            |Bachelors degree in Software Engineering or related.                                                                         |[Bac+3]                                                                |[CDI, CDD - Freelance]                                                      |Dakar - Diourbel - Fatick - Kaffrine - Kaolack - Kédougou - Kolda|[Expérience entre 5 ans et 10 ans]       |[AGILE, ANGULAR JS, AZURE, BIG DATA, CASSANDRA, COUCHBASE, CSS, CVS, DOCKER, GIT, HADOOP, HIBERNATE, HTML, J2EE, JAVA, JAVA JEE, JAVASCRIPT, JBOSS, JENKINS, MAVEN, MVC, MYSQL, NOSQL, ORACLE, REDIS, REST, SOAP, SPARK, SPRING, SQL, STRUTS, WEBLOGIC]|
# |TIENS DS COM          |Assistante Personnelle de Direction - Dakar          |Dakar & International                                            |05.08.2025         |NULL|NULL            |Discrétion et Loyauté                                                                                                        |[Bac+3, Bac+4, Bac+5, plus]                                            |[CDI, CDD]                                                                  |Dakar & International                                            |[Expérience entre 2 ans et 5 ans et plus]|[Gestion, Management, Planification]                                                                                                                                                                                                                   |
# |TECTRA SÉNÉGAL        |Assistant Directeur d´Usine  - Dakar                 |Dakar                                                            |26.06.2025         |NULL|NULL            |Bac + 3 en administration des affaires, en gestion industrielle, en ingénierie ou dans un domaine connexe.                   |[Bac+3]                                                                |[CDD]                                                                       |Dakar                                                            |[Expérience entre 2 ans et 5 ans et plus]|[Fabrication, Gestion Industrielle, Industrie, Maintenance, Normes de Qualité, Processus, Production, Productivité, Qualité, Techniques de Production]                                                                                                 |
# |SENEA FOOD            |Planificateur(trice) Production - Ouakam             |Dakar                                                            |30.06.2025         |NULL|NULL            |Expérience confirmée en planification ou production, idéalement en agro-alimentaire.                                         |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[CDI, CDD, Intérim, Stage, Freelance, Alternance, Temps partiel, Statutaire]|Dakar                                                            |[Expérience entre 2 ans et 5 ans et plus]|[Amélioration Continue, Fluide, Maintenance, Production, Productivité, Qualité]                                                                                                                                                                        |
# +----------------------+-----------------------------------------------------+-----------------------------------------------------------------+-------------------+----+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------------------------------------------------------------+-----------------------------------------------------------------+-----------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# # INgection a notre dataWarehouse

# %%
### ---------------------- nos liens --------------------------------------------####
url = "jdbc:postgresql://postgres_warehouse:5432/Warehouse_DB"
user = "admin"
password = "admin_pwd"
driver = "org.postgresql.Driver"

# %% [markdown]
# ## Creation de la table du ml

# %%
###---------------Creation du dataset ML --------------------------------####

df_ml.write\
    .format("jdbc")\
    .option("url", url)\
    .option("dbtable","dataset_ml")\
    .option("user", user)\
    .option("password",password)\
    .option("driver", driver)\
    .mode("append")\
    .save()

# %%
df_ml.show(truncate=False)
# Out:
# [Stage 150:================================>                        (4 + 2) / 7]
# +----------------+-----------------------------------+----+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+------------------+
# |entreprise      |poste                              |lien|competence    |formation                            |niveau_etude           |contrat|experience           |region       |date_de_pulication|
# +----------------+-----------------------------------+----+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+------------------+
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|CDI    |Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|CDI    |jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|Intérim|Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|Intérim|jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |CDI    |Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |CDI    |jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |Intérim|Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |Intérim|jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+1                  |CDI    |Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+1                  |CDI    |jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+1                  |Intérim|Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+1                  |Intérim|jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+2                  |CDI    |Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+2                  |CDI    |jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+2                  |Intérim|Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+2                  |Intérim|jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+3                  |CDI    |Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+3                  |CDI    |jeune diplômé et plus|International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+3                  |Intérim|Etudiant             |International|20.06.2025        |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|NULL|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+3                  |Intérim|jeune diplômé et plus|International|20.06.2025        |
# +----------------+-----------------------------------+----+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### Creation de la table simple (normmale)

# %%
##########___-------Mise en forme----------__________________________###
df_propres = df_clean.select("entreprise", "poste", col("competences").alias("competence"),
col("formation_clean").alias("formation"), col("niveau_etude_clean").alias("niveau_etude"),
col("contract").alias("contrat"), col("experience").alias("experience"),"lien",
col("region_clean").alias("region"), col("date_de_publication").alias("date_de_publication")
)

# %%
df_propres.write\
    .format("jdbc")\
    .option("url", url)\
    .option("dbtable","offres_emploi")\
    .option("user", user)\
    .option("password",password)\
    .option("driver", driver)\
    .mode("append")\
    .save()

# %%
df_lecture = spark.read \
    .format("jdbc") \
    .option("url", url) \
    .option("dbtable", "offres_emploi") \
    .option("user", user) \
    .option("password", password) \
    .option("driver", driver) \
    .load()

# %%
df_lecture.show(5, truncate=False)
# Out:
# +----------------+-----------------------------------------------------+--------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------+-----------------------------------------+----+-----------------------------------------------------------------+-------------------+
# |entreprise      |poste                                                |competence                                                                                              |formation                                                                                                                    |niveau_etude                                                           |contrat               |experience                               |lien|region                                                           |date_de_publication|
# +----------------+-----------------------------------------------------+--------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------+-----------------------------------------+----+-----------------------------------------------------------------+-------------------+
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)                  |[Accompagnement, Assemblage, Emballage, Maintenance, Production, Qualité, Sécurité]                     |Niveau d’anglais intermédiaire requis                                                                                        |[Qualification avant bac, Bac, Bac+1, Bac+2, Bac+3, Bac+4, Bac+5, plus]|[CDI, Intérim]        |[Etudiant, jeune diplômé et plus]        |NULL|International                                                    |20.06.2025         |
# |TALIACOM        |Graphiste - Dakar                                    |[CMS]                                                                                                   |Vous acquérez votre licence Kuik.fr à un tarif préférentiel                                                                  |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[Stage, Freelance]    |[Expérience entre 2 ans et 5 ans et plus]|NULL|Dakar - Thiès & International                                    |01.08.2025         |
# |CABINET CARREE  |Responsable Administratif et Financier Senior - Dakar|[Comptabilité, Comptabilité Générale, États Financiers, Finance, Financement, Gestion, IFRS, Trésorerie]|Formation supérieure en finance, comptabilité, gestion (Bac +5 minimum – type Master CCA, DSCG, MBF, école de commerce, etc.)|[Bac+5, plus]                                                          |[CDI]                 |[Expérience entre 5 ans et 10 ans]       |NULL|Dakar                                                            |01.07.2025         |
# |ONE TO ONE      |Expert SEO Confirmé (H/F)  - Télétravail             |[Netlinking, Positionnement, Référencement Naturel, Référencement SEO, SEO]                             |Minimum 3 ans d’expérience prouvée en SEO (idéalement en agence ou en freelance multi-clients)                               |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[CDI, Freelance]      |[Expérience entre 2 ans et 5 ans et plus]|NULL|International                                                    |07.07.2025         |
# |AFRICASHORE     |Cloud System Integrator (M/F)                        |[AGILE, CVS]                                                                                            |Bachelors degree in Cloud Computing or related.                                                                              |[Bac+3]                                                                |[CDI, CDD - Freelance]|[Expérience entre 5 ans et 10 ans]       |NULL|Dakar - Diourbel - Fatick - Kaffrine - Kaolack - Kédougou - Kolda|04.06.2025         |
# +----------------+-----------------------------------------------------+--------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------+-----------------------------------------+----+-----------------------------------------------------------------+-------------------+
# only showing top 5 rows

# %%
df_result = df_lecture.select("date_de_publication")

df_result.distinct().show(100, truncate=False)
# Out:
# +--------------------------+
# |date_de_publication       |
# +--------------------------+
# |16.06.2025                |
# |30.06.2025                |
# |29.07.2025                |
# |Publié le 7 novembre 2025 |
# |04.07.2025                |
# |08.08.2025                |
# |Publié le 8 novembre 2025 |
# |Publié le 22 novembre 2025|
# |02.08.2025                |
# |11.06.2025                |
# |12.06.2025                |
# |Publié le 25 novembre 2025|
# |Publié le 20 novembre 2025|
# |Publié le 24 novembre 2025|
# |25.07.2025                |
# |05.08.2025                |
# |16.07.2025                |
# |06.08.2025                |
# |13.06.2025                |
# |Publié le 2 décembre 2025 |
# |11.07.2025                |
# |Publié le 28 novembre 2025|
# |Publié le 23 novembre 2025|
# |20.06.2025                |
# |21.07.2025                |
# |01.07.2025                |
# |Publié le 4 décembre 2025 |
# |Publié le 14 novembre 2025|
# |10.06.2025                |
# |10.07.2025                |
# |02.07.2025                |
# |Publié le 5 décembre 2025 |
# |Publié le 19 novembre 2025|
# |25.06.2025                |
# |07.07.2025                |
# |21.06.2025                |
# |Publié le 3 décembre 2025 |
# |Publié le 26 novembre 2025|
# |07.08.2025                |
# |31.07.2025                |
# |19.07.2025                |
# |15.07.2025                |
# |04.08.2025                |
# |Publié le 6 décembre 2025 |
# |17.06.2025                |
# |14.07.2025                |
# |26.06.2025                |
# |24.06.2025                |
# |Publié le 17 novembre 2025|
# |Publié le 1 décembre 2025 |
# |Publié le 13 novembre 2025|
# |Publié le 10 novembre 2025|
# |09.07.2025                |
# |Publié le 27 novembre 2025|
# |23.06.2025                |
# |24.07.2025                |
# |01.08.2025                |
# |17.07.2025                |
# |19.06.2025                |
# |04.06.2025                |
# |18.06.2025                |
# |Publié le 18 novembre 2025|
# |NULL                      |
# +--------------------------+

# %%
spark.stop()

# %%
del spark
