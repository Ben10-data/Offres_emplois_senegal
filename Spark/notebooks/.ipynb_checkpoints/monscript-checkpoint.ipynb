# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, explode, regexp_replace,  date_format,  when, udf, to_date
from pyspark.sql import functions as F 
from pyspark.sql.types import DateType
from datetime import datetime

# %%
try:
   spark.stop()
except:
     pass 

spark = SparkSession.builder\
        .appName('traitement_NLP').getOrCreate()

# %%
# version de la version de spark 
spark.version
# Out:
# '3.5.7'

# %%
# lecture de nos fichier hdfs 
df = spark.read.option("mergeSchema", "true").parquet("hdfs://namenode:8020/ben/dataLake/")
df.count()
# Out:
# 10335

# %%
df = df.dropDuplicates()
# compter les nombres de lignes qu'on a 
df.count()
# Out:
# 488

# %%
# voir le schema ou les differents colonnes de nos données 
df.printSchema()
# Out:
# root
#  |-- poste: string (nullable = true)
#  |-- lien: string (nullable = true)
#  |-- entreprise: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- contract_propose: string (nullable = true)
#  |-- date_de_publication: string (nullable = true)
#  |-- niveau_etude: string (nullable = true)
#  |-- niveau_experience: string (nullable = true)
#  |-- contrat_propose: string (nullable = true)
#  |-- Competence: string (nullable = true)
#  |-- formation: string (nullable = true)

# %%
# Les nombres de differents poste et  entreprises existantes 
df.select("poste").distinct().count()
# Out:
# 461

# %%
df.select("entreprise").distinct().count()

#----------------- *** Colonnes a nettoyer et organiser ***-----------------------#
# Apres un passage de select, exemple la colonne suivant '"entreprise"
df.select("entreprise").distinct().show(5, truncate=False)
# Out:
# +------------------+
# |entreprise        |
# +------------------+
# |Plan International|
# |Adm Value Sénégal |
# |CEVA Logistics    |
# |Kuikdel           |
# |TECTRA SÉNÉGAL    |
# +------------------+
# only showing top 5 rows

# %%
###------------- traitement de chaque colonne -------------------------------- ###### 

# ---------------- pour la colonne formation 

df_formation = df.withColumn(
    "formation_clean",
    F.trim(
        F.regexp_replace(F.col("formation"), r"</li><li>", ", "))
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.regexp_replace(F.col("formation_clean"), r"</?li>", "")
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.regexp_replace(F.col("formation_clean"), r"[\n]", "")
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.regexp_replace(F.col("formation_clean"),r"</?strong>", "")
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.trim(F.regexp_replace(F.col("formation_clean"), r"<[^>]+>", ""))
)

df_formation.drop("formation")
# Out:
# DataFrame[poste: string, lien: string, entreprise: string, region: string, contract_propose: string, date_de_publication: string, niveau_etude: string, niveau_experience: string, contrat_propose: string, Competence: string, formation_clean: string]

# %%
#-------------- Pour la colonne niveau_etude--------------

df_etude = df_formation.withColumn(
    "niveau_etude_clean",
    split(col("niveau_etude"), r"\s*(?:,|&|et)\s*")
)

df_etude = df_etude.drop("niveau_etude")
df_etude = df_etude.drop("formation")

# %%
##------------ contract proposé ---------------------------
df_contract = df_etude.withColumn(
    "contract",
    split(col("contrat_propose"), r"\s*(?:,|&|et)\s*")
)

df_contract = df_contract.drop("contrat_propose")

# %%
### ------------- Pour la region 

df_region = df_contract.withColumn(
    "region_clean",
    F.trim(F.regexp_replace(F.col("region"), r"\s*(?:\n|\t)", ""))

)

df_region = df_region.drop("region")

# %%
# ----- experience 

df_experience = df_region.withColumn(
    "experience", 
    split(col("niveau_experience"), r"\s*(?:,|&|-)\s*")
)

df_experience = df_experience.drop("niveau_experience")

# %%
#---------- Traitement des competences 

df_competence = df_experience.withColumn(
    "competences",
    split(col("Competence"), r"\s*(-)\s*")
)

# %%
#------- Traitement des dates --- Nombre de date avant traitement 
df_date = df_competence.count()
df_date
# Out:
# 488

# %%
df_competence.show()
# Out:
# +--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |               poste|                lien|          entreprise|contract_propose| date_de_publication|          Competence|     formation_clean|  niveau_etude_clean|            contract|        region_clean|          experience|         competences|
# +--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |Ouvrier d’Usine -...|                NULL|    INTRA INTERIM SN|            NULL|          20.06.2025|Accompagnement - ...|Niveau d’anglais ...|[Qualification av...|      [CDI, Intérim]|       International|[Etudiant, jeune ...|[Accompagnement, ...|
# |Tailleur Costume ...|https://www.emplo...|          Ûssû suits|             CDD|                NULL|                NULL|                NULL|                NULL|                NULL|Liberté 6 extensi...|                NULL|                NULL|
# |10 Business Devel...|https://www.emplo...|       Groupe Taliso|             CDD|                NULL|                NULL|                NULL|                NULL|                NULL|      Dakar, Sénégal|                NULL|                NULL|
# |Responsable Admin...|                NULL|      CABINET CARREE|            NULL|          01.07.2025|Comptabilité - Co...|Formation supérie...|       [Bac+5, plus]|               [CDI]|               Dakar|[Expérience entre...|[Comptabilité, Co...|
# |Expert SEO Confir...|                NULL|          ONE TO ONE|            NULL|          07.07.2025|Netlinking - Posi...|Minimum 3 ans d’e...|[Bac+2, Bac+3, Ba...|    [CDI, Freelance]|       International|[Expérience entre...|[Netlinking, Posi...|
# |   Graphiste - Dakar|                NULL|            TALIACOM|            NULL|          01.08.2025|                 CMS|Vous acquérez vot...|[Bac+2, Bac+3, Ba...|  [Stage, Freelance]|Dakar - Thiès & I...|[Expérience entre...|               [CMS]|
# |Préparateur(trice...|https://www.emplo...|Grazeina Technolo...|             CDD|                NULL|                NULL|                NULL|                NULL|                NULL|      Point E, Dakar|                NULL|                NULL|
# |Traducteurs profe...|https://www.emplo...|              MGtrad|             CDI|Publié le 7 avril...|                NULL|                NULL|                NULL|                NULL|Sénégal (Télétrav...|                NULL|                NULL|
# |Officer, Liveliho...|https://www.emplo...|                IFRC|             CDD|Publié le 26 mars...|                NULL|                NULL|                NULL|                NULL|      Dakar, Sénégal|                NULL|                NULL|
# |Cloud System Inte...|                NULL|         AFRICASHORE|            NULL|          04.06.2025|         AGILE - CVS|Bachelors degree ...|             [Bac+3]|[CDI, CDD - Freel...|Dakar - Diourbel ...|[Expérience entre...|        [AGILE, CVS]|
# |Merchant Distribu...|https://www.emplo...|   Wave Mobile Money|             CDD|Publié le 26 mars...|                NULL|                NULL|                NULL|                NULL|      Dakar, Sénégal|                NULL|                NULL|
# |Stagiaire en Qual...|                NULL|REGARD GLOBAL SER...|            NULL|          16.06.2025|3D 2D - 4D - Nett...| Minimum niveau BFEM|[Qualification av...|             [Stage]|               Dakar|[Etudiant, jeune ...|[3D 2D, 4D, Netto...|
# |Responsable Natio...|https://www.emplo...|Organisation Inte...|             CDD|Publié le 8 avril...|                NULL|                NULL|                NULL|                NULL|      Dakar, Sénégal|                NULL|                NULL|
# |         Commerciaux|https://www.emplo...| Société de la place|             CDD|Publié le 31 mars...|                NULL|                NULL|                NULL|                NULL|      Dakar, Sénégal|                NULL|                NULL|
# |JAVA JEE Develope...|                NULL|         AFRICASHORE|            NULL|          04.06.2025|AGILE - ANGULAR J...|Bachelors degree ...|             [Bac+3]|[CDI, CDD - Freel...|Dakar - Diourbel ...|[Expérience entre...|[AGILE, ANGULAR J...|
# |People Operations...|https://www.emplo...|              Myriad|             CDD|                NULL|                NULL|                NULL|                NULL|                NULL|      Dakar, Sénégal|                NULL|                NULL|
# |       Chargé de SIG|https://www.emplo...|              IMPACT|             CDD|Publié le 7 avril...|                NULL|                NULL|                NULL|                NULL|      Dakar, Sénégal|                NULL|                NULL|
# |Responsable régional|https://www.emplo...|        Pulse et PPI|             CDI|Publié le 27 mars...|                NULL|                NULL|                NULL|                NULL|      Dakar, Sénégal|                NULL|                NULL|
# |Assistante Person...|                NULL|        TIENS DS COM|            NULL|          05.08.2025|Gestion - Managem...|Discrétion et Loy...|[Bac+3, Bac+4, Ba...|          [CDI, CDD]|Dakar & Internati...|[Expérience entre...|[Gestion, Managem...|
# |Assistant Directe...|                NULL|      TECTRA SÉNÉGAL|            NULL|          26.06.2025|Fabrication - Ges...|Bac + 3 en admini...|             [Bac+3]|               [CDD]|               Dakar|[Expérience entre...|[Fabrication, Ges...|
# +--------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
df_date_nettoyer = df_competence.withColumn(
    "date_convertie",
    regexp_replace(col("date_de_publication"), "Publié le ", "")
)

# %%
df_date_nettoyer.count()
# Out:
# 488

# %%
df_date_nettoyer.select("date_de_publication","date_convertie").distinct().show()
# Out:
# +--------------------+--------------+
# | date_de_publication|date_convertie|
# +--------------------+--------------+
# |          12.06.2025|    12.06.2025|
# |          31.07.2025|    31.07.2025|
# |Publié le 6 avril...|  6 avril 2026|
# |          17.07.2025|    17.07.2025|
# |          21.07.2025|    21.07.2025|
# |Publié le 31 mars...|  31 mars 2026|
# |          29.07.2025|    29.07.2025|
# |          23.06.2025|    23.06.2025|
# |          04.07.2025|    04.07.2025|
# |Publié le 3 mars ...|   3 mars 2026|
# |          13.06.2025|    13.06.2025|
# |          25.06.2025|    25.06.2025|
# |          14.07.2025|    14.07.2025|
# |          02.08.2025|    02.08.2025|
# |Publié le 23 mars...|  23 mars 2026|
# |          04.06.2025|    04.06.2025|
# |Publié le 25 mars...|  25 mars 2026|
# |          09.07.2025|    09.07.2025|
# |          19.07.2025|    19.07.2025|
# |          10.06.2025|    10.06.2025|
# +--------------------+--------------+
# only showing top 20 rows

# %%
# Fonction pour convertir les deux formats des dates 
def parse_date(date_str):
    if date_str is None:
        return None
    try:
        # Format 1: "12.06.2025"
        if "." in date_str and len(date_str.split(".")) == 3:
            return datetime.strptime(date_str, "%d.%m.%Y").date()
        
        # Format 2: "6 avril 2026"
        else:
            mois_fr_to_en = {
                'janvier': 'January', 'février': 'February', 'mars': 'March',
                'avril': 'April', 'mai': 'May', 'juin': 'June',
                'juillet': 'July', 'août': 'August', 'septembre': 'September',
                'octobre': 'October', 'novembre': 'November', 'décembre': 'December'
            }
            parts = date_str.split()
            if len(parts) >= 3:
                jour = parts[0].zfill(2)
                mois_fr = parts[1]
                annee = parts[2]
                mois_en = mois_fr_to_en.get(mois_fr, mois_fr)
                return datetime.strptime(f"{jour} {mois_en} {annee}", "%d %B %Y").date()
    except:
        return None
    return None

# Appliquer la conversion
parse_date_udf = udf(parse_date, DateType())
df_date_formatee = df_date_nettoyer.withColumn(
    "date_typee", 
    parse_date_udf(col("date_convertie"))
)

# %%
# Vérifier
df_date_formatee.select("date_de_publication","date_convertie", "date_typee").show(10, truncate=False)
# Out:
# +----------------------+--------------+----------+
# |date_de_publication   |date_convertie|date_typee|
# +----------------------+--------------+----------+
# |20.06.2025            |20.06.2025    |2025-06-20|
# |NULL                  |NULL          |NULL      |
# |NULL                  |NULL          |NULL      |
# |01.07.2025            |01.07.2025    |2025-07-01|
# |07.07.2025            |07.07.2025    |2025-07-07|
# |01.08.2025            |01.08.2025    |2025-08-01|
# |NULL                  |NULL          |NULL      |
# |Publié le 7 avril 2026|7 avril 2026  |2026-04-07|
# |Publié le 26 mars 2026|26 mars 2026  |2026-03-26|
# |04.06.2025            |04.06.2025    |2025-06-04|
# +----------------------+--------------+----------+
# only showing top 10 rows

# %%
df_date_formatee.count()
# Out:
# 488

# %%
df_date_formatee.select("date_de_publication","date_convertie", "date_typee").distinct().show(100)
# Out:
# +--------------------+--------------+----------+
# | date_de_publication|date_convertie|date_typee|
# +--------------------+--------------+----------+
# |Publié le 4 avril...|  4 avril 2026|2026-04-04|
# |          14.07.2025|    14.07.2025|2025-07-14|
# |          15.07.2025|    15.07.2025|2025-07-15|
# |          29.07.2025|    29.07.2025|2025-07-29|
# |          07.08.2025|    07.08.2025|2025-08-07|
# |Publié le 9 avril...|  9 avril 2026|2026-04-09|
# |Publié le 12 mars...|  12 mars 2026|2026-03-12|
# |          17.07.2025|    17.07.2025|2025-07-17|
# |          10.07.2025|    10.07.2025|2025-07-10|
# |          19.06.2025|    19.06.2025|2025-06-19|
# |          04.06.2025|    04.06.2025|2025-06-04|
# |Publié le 25 mars...|  25 mars 2026|2026-03-25|
# |          11.06.2025|    11.06.2025|2025-06-11|
# |          04.07.2025|    04.07.2025|2025-07-04|
# |          08.08.2025|    08.08.2025|2025-08-08|
# |Publié le 13 avri...| 13 avril 2026|2026-04-13|
# |          01.07.2025|    01.07.2025|2025-07-01|
# |          24.06.2025|    24.06.2025|2025-06-24|
# |          11.07.2025|    11.07.2025|2025-07-11|
# |          07.07.2025|    07.07.2025|2025-07-07|
# |          06.08.2025|    06.08.2025|2025-08-06|
# |          02.07.2025|    02.07.2025|2025-07-02|
# |          16.07.2025|    16.07.2025|2025-07-16|
# |          04.08.2025|    04.08.2025|2025-08-04|
# |          09.07.2025|    09.07.2025|2025-07-09|
# |Publié le 11 mars...|  11 mars 2026|2026-03-11|
# |          17.06.2025|    17.06.2025|2025-06-17|
# |          19.07.2025|    19.07.2025|2025-07-19|
# |          18.06.2025|    18.06.2025|2025-06-18|
# |          13.06.2025|    13.06.2025|2025-06-13|
# |Publié le 7 avril...|  7 avril 2026|2026-04-07|
# |          10.06.2025|    10.06.2025|2025-06-10|
# |Publié le 17 mars...|  17 mars 2026|2026-03-17|
# |          20.06.2025|    20.06.2025|2025-06-20|
# |Publié le 8 avril...|  8 avril 2026|2026-04-08|
# |Publié le 26 mars...|  26 mars 2026|2026-03-26|
# |          30.06.2025|    30.06.2025|2025-06-30|
# |          24.07.2025|    24.07.2025|2025-07-24|
# |          02.08.2025|    02.08.2025|2025-08-02|
# |          26.06.2025|    26.06.2025|2025-06-26|
# |          31.07.2025|    31.07.2025|2025-07-31|
# |Publié le 30 mars...|  30 mars 2026|2026-03-30|
# |          21.06.2025|    21.06.2025|2025-06-21|
# |Publié le 1 avril...|  1 avril 2026|2026-04-01|
# |Publié le 18 mars...|  18 mars 2026|2026-03-18|
# |Publié le 31 mars...|  31 mars 2026|2026-03-31|
# |Publié le 3 mars ...|   3 mars 2026|2026-03-03|
# |Publié le 2 avril...|  2 avril 2026|2026-04-02|
# |          01.08.2025|    01.08.2025|2025-08-01|
# |          05.08.2025|    05.08.2025|2025-08-05|
# |          21.07.2025|    21.07.2025|2025-07-21|
# |Publié le 3 avril...|  3 avril 2026|2026-04-03|
# |Publié le 6 avril...|  6 avril 2026|2026-04-06|
# |          12.06.2025|    12.06.2025|2025-06-12|
# |Publié le 27 mars...|  27 mars 2026|2026-03-27|
# |          25.06.2025|    25.06.2025|2025-06-25|
# |Publié le 23 mars...|  23 mars 2026|2026-03-23|
# |          16.06.2025|    16.06.2025|2025-06-16|
# |          25.07.2025|    25.07.2025|2025-07-25|
# |          23.06.2025|    23.06.2025|2025-06-23|
# |Publié le 24 mars...|  24 mars 2026|2026-03-24|
# |Publié le 11 avri...| 11 avril 2026|2026-04-11|
# |Publié le 19 mars...|  19 mars 2026|2026-03-19|
# |Publié le 10 avri...| 10 avril 2026|2026-04-10|
# |                NULL|          NULL|      NULL|
# +--------------------+--------------+----------+

# %%
df_2026 = df_date_formatee.filter(df_date_formatee.date_typee.contains("2026"))
df_2026.select("date_typee").show(truncate=False)
# Out:
# +----------+
# |date_typee|
# +----------+
# |2026-04-07|
# |2026-03-26|
# |2026-03-26|
# |2026-04-08|
# |2026-03-31|
# |2026-04-07|
# |2026-03-27|
# |2026-03-30|
# |2026-04-08|
# |2026-03-24|
# |2026-04-03|
# |2026-04-02|
# |2026-04-01|
# |2026-04-03|
# |2026-03-30|
# |2026-03-27|
# |2026-04-01|
# |2026-04-03|
# |2026-04-01|
# |2026-04-08|
# +----------+
# only showing top 20 rows

# %%
df_date_formatee.printSchema()
# Out:
# root
#  |-- poste: string (nullable = true)
#  |-- lien: string (nullable = true)
#  |-- entreprise: string (nullable = true)
#  |-- contract_propose: string (nullable = true)
#  |-- date_de_publication: string (nullable = true)
#  |-- Competence: string (nullable = true)
#  |-- formation_clean: string (nullable = true)
#  |-- niveau_etude_clean: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- contract: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- region_clean: string (nullable = true)
#  |-- experience: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- competences: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- date_convertie: string (nullable = true)
#  |-- date_typee: date (nullable = true)

# %%
###---------------------------------------------------------------------------------#######""
#------------------------------------------------------------------------------------#
# Creation de la premiere dataset qui contient toutes les données 

df_clean = df_date_formatee.drop("Competence")
df_clean = df_clean.drop("date_convertie","date_de_publication")


df_clean.show(5, truncate=False)
# Out:
# +-----------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------+----------------+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------+--------------------------+-----------------------------------------+--------------------------------------------------------------------------------------------------------+----------+
# |poste                                                |lien                                                                                                                                |entreprise      |contract_propose|formation_clean                                                                                                              |niveau_etude_clean                                                     |contract        |region_clean              |experience                               |competences                                                                                             |date_typee|
# +-----------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------+----------------+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------+--------------------------+-----------------------------------------+--------------------------------------------------------------------------------------------------------+----------+
# |Ouvrier d’Usine - Roumanie (Europe)                  |NULL                                                                                                                                |INTRA INTERIM SN|NULL            |Niveau d’anglais intermédiaire requis                                                                                        |[Qualification avant bac, Bac, Bac+1, Bac+2, Bac+3, Bac+4, Bac+5, plus]|[CDI, Intérim]  |International             |[Etudiant, jeune diplômé et plus]        |[Accompagnement, Assemblage, Emballage, Maintenance, Production, Qualité, Sécurité]                     |2025-06-20|
# |Tailleur Costume sur mesure                          |https://www.emploidakar.com/offre-demploi/ussu-suits-liberte-6-extension-cdd-cdi-prestation-de-services-tailleur-costume-sur-mesure/|Ûssû suits      |CDD             |NULL                                                                                                                         |NULL                                                                   |NULL            |Liberté 6 extension, Dakar|NULL                                     |NULL                                                                                                    |NULL      |
# |10 Business Developers                               |https://www.emploidakar.com/offre-demploi/groupe-taliso-dakar-cdd-prestation-de-services-stage-business-developer/                  |Groupe Taliso   |CDD             |NULL                                                                                                                         |NULL                                                                   |NULL            |Dakar, Sénégal            |NULL                                     |NULL                                                                                                    |NULL      |
# |Responsable Administratif et Financier Senior - Dakar|NULL                                                                                                                                |CABINET CARREE  |NULL            |Formation supérieure en finance, comptabilité, gestion (Bac +5 minimum – type Master CCA, DSCG, MBF, école de commerce, etc.)|[Bac+5, plus]                                                          |[CDI]           |Dakar                     |[Expérience entre 5 ans et 10 ans]       |[Comptabilité, Comptabilité Générale, États Financiers, Finance, Financement, Gestion, IFRS, Trésorerie]|2025-07-01|
# |Expert SEO Confirmé (H/F)  - Télétravail             |NULL                                                                                                                                |ONE TO ONE      |NULL            |Minimum 3 ans d’expérience prouvée en SEO (idéalement en agence ou en freelance multi-clients)                               |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[CDI, Freelance]|International             |[Expérience entre 2 ans et 5 ans et plus]|[Netlinking, Positionnement, Référencement Naturel, Référencement SEO, SEO]                             |2025-07-07|
# +-----------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------+----------------+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------+--------------------------+-----------------------------------------+--------------------------------------------------------------------------------------------------------+----------+
# only showing top 5 rows

# %%
print("dataset normale sur les offres")
df_clean.show(10, truncate=False)
# Out:
# dataset normale sur les offres
# +--------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------+-----------------------------------------------------------------+-----------------------------------------+--------------------------------------------------------------------------------------------------------+----------+
# |poste                                                               |lien                                                                                                                                                       |entreprise           |contract_propose|formation_clean                                                                                                              |niveau_etude_clean                                                     |contract              |region_clean                                                     |experience                               |competences                                                                                             |date_typee|
# +--------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------+-----------------------------------------------------------------+-----------------------------------------+--------------------------------------------------------------------------------------------------------+----------+
# |Ouvrier d’Usine - Roumanie (Europe)                                 |NULL                                                                                                                                                       |INTRA INTERIM SN     |NULL            |Niveau d’anglais intermédiaire requis                                                                                        |[Qualification avant bac, Bac, Bac+1, Bac+2, Bac+3, Bac+4, Bac+5, plus]|[CDI, Intérim]        |International                                                    |[Etudiant, jeune diplômé et plus]        |[Accompagnement, Assemblage, Emballage, Maintenance, Production, Qualité, Sécurité]                     |2025-06-20|
# |Tailleur Costume sur mesure                                         |https://www.emploidakar.com/offre-demploi/ussu-suits-liberte-6-extension-cdd-cdi-prestation-de-services-tailleur-costume-sur-mesure/                       |Ûssû suits           |CDD             |NULL                                                                                                                         |NULL                                                                   |NULL                  |Liberté 6 extension, Dakar                                       |NULL                                     |NULL                                                                                                    |NULL      |
# |10 Business Developers                                              |https://www.emploidakar.com/offre-demploi/groupe-taliso-dakar-cdd-prestation-de-services-stage-business-developer/                                         |Groupe Taliso        |CDD             |NULL                                                                                                                         |NULL                                                                   |NULL                  |Dakar, Sénégal                                                   |NULL                                     |NULL                                                                                                    |NULL      |
# |Responsable Administratif et Financier Senior - Dakar               |NULL                                                                                                                                                       |CABINET CARREE       |NULL            |Formation supérieure en finance, comptabilité, gestion (Bac +5 minimum – type Master CCA, DSCG, MBF, école de commerce, etc.)|[Bac+5, plus]                                                          |[CDI]                 |Dakar                                                            |[Expérience entre 5 ans et 10 ans]       |[Comptabilité, Comptabilité Générale, États Financiers, Finance, Financement, Gestion, IFRS, Trésorerie]|2025-07-01|
# |Expert SEO Confirmé (H/F)  - Télétravail                            |NULL                                                                                                                                                       |ONE TO ONE           |NULL            |Minimum 3 ans d’expérience prouvée en SEO (idéalement en agence ou en freelance multi-clients)                               |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[CDI, Freelance]      |International                                                    |[Expérience entre 2 ans et 5 ans et plus]|[Netlinking, Positionnement, Référencement Naturel, Référencement SEO, SEO]                             |2025-07-07|
# |Graphiste - Dakar                                                   |NULL                                                                                                                                                       |TALIACOM             |NULL            |Vous acquérez votre licence Kuik.fr à un tarif préférentiel                                                                  |[Bac+2, Bac+3, Bac+4, Bac+5, plus]                                     |[Stage, Freelance]    |Dakar - Thiès & International                                    |[Expérience entre 2 ans et 5 ans et plus]|[CMS]                                                                                                   |2025-08-01|
# |Préparateur(trice) de Devis Informatique (Profil Systèmes & Réseaux)|https://www.emploidakar.com/offre-demploi/grazeina-technologies-point-e-dakar-senegal-stage-preparateurtrice-de-devis-informatique-profil-systemes-reseaux/|Grazeina Technologies|CDD             |NULL                                                                                                                         |NULL                                                                   |NULL                  |Point E, Dakar                                                   |NULL                                     |NULL                                                                                                    |NULL      |
# |Traducteurs professionnels                                          |https://www.emploidakar.com/offre-demploi/mgtrad-4ieme-etage-56-av-lalla-yacout-casablanca-20100-cdi-recherche-traducteurs-professionnels/                 |MGtrad               |CDI             |NULL                                                                                                                         |NULL                                                                   |NULL                  |Sénégal (Télétravail)                                            |NULL                                     |NULL                                                                                                    |2026-04-07|
# |Officer, Livelihoods & Resilience                                   |https://www.emploidakar.com/offre-demploi/ifrc-dakar-senegal-cdd-officer-livelihoods-resilience/                                                           |IFRC                 |CDD             |NULL                                                                                                                         |NULL                                                                   |NULL                  |Dakar, Sénégal                                                   |NULL                                     |NULL                                                                                                    |2026-03-26|
# |Cloud System Integrator (M/F)                                       |NULL                                                                                                                                                       |AFRICASHORE          |NULL            |Bachelors degree in Cloud Computing or related.                                                                              |[Bac+3]                                                                |[CDI, CDD - Freelance]|Dakar - Diourbel - Fatick - Kaffrine - Kaolack - Kédougou - Kolda|[Expérience entre 5 ans et 10 ans]       |[AGILE, CVS]                                                                                            |2025-06-04|
# +--------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+----------------+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+----------------------+-----------------------------------------------------------------+-----------------------------------------+--------------------------------------------------------------------------------------------------------+----------+
# only showing top 10 rows

# %%
#### ---------------- Creation du dataSet normale -------------------------###


##########___-------Mise en forme----------__________________________###
df_propres = df_clean.select("entreprise", "poste", col("competences").alias("competence"),
col("formation_clean").alias("formation"), col("niveau_etude_clean").alias("niveau_etude"),
col("contract").alias("contrat"), col("experience").alias("experience"),
col("region_clean").alias("region"), col("date_typee").alias("date_de_publication")
)

# %%
# Creation du deuxieme dataset pour le machine learning

df_ml = df_clean.select("entreprise", "poste", explode(col("competences")).alias("competence"),
col("formation_clean").alias("formation"), explode(col("niveau_etude_clean")).alias("niveau_etude"),
explode(col("contract")).alias("contrat"), explode(col("experience")).alias("experience"),
col("region_clean").alias("region"), col("date_typee").alias("date_de_publication")
)


print("dataset pour le machine learning et l'analyse analytique")
df_ml.show(10, truncate=False)
# Out:
# dataset pour le machine learning et l'analyse analytique
# +----------------+-----------------------------------+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+-------------------+
# |entreprise      |poste                              |competence    |formation                            |niveau_etude           |contrat|experience           |region       |date_de_publication|
# +----------------+-----------------------------------+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+-------------------+
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|CDI    |Etudiant             |International|2025-06-20         |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|CDI    |jeune diplômé et plus|International|2025-06-20         |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|Intérim|Etudiant             |International|2025-06-20         |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Qualification avant bac|Intérim|jeune diplômé et plus|International|2025-06-20         |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |CDI    |Etudiant             |International|2025-06-20         |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |CDI    |jeune diplômé et plus|International|2025-06-20         |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |Intérim|Etudiant             |International|2025-06-20         |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Bac                    |Intérim|jeune diplômé et plus|International|2025-06-20         |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+1                  |CDI    |Etudiant             |International|2025-06-20         |
# |INTRA INTERIM SN|Ouvrier d’Usine - Roumanie (Europe)|Accompagnement|Niveau d’anglais intermédiaire requis|Bac+1                  |CDI    |jeune diplômé et plus|International|2025-06-20         |
# +----------------+-----------------------------------+--------------+-------------------------------------+-----------------------+-------+---------------------+-------------+-------------------+
# only showing top 10 rows

# %%
### ---------------------- nos liens --------------------------------------------####
url = "jdbc:postgresql://postgres_warehouse:5432/datawarehouse"
user = "admin"
password = "admin_pwd"
driver = "org.postgresql.Driver"

# %%
df_propres.write\
    .format("jdbc")\
    .option("url", url)\
    .option("dbtable","offres_emploi")\
    .option("user", user)\
    .option("password",password)\
    .option("driver", driver)\
    .mode("append")\
    .save()

# %%
###---------------Creation du dataset ML --------------------------------####

df_ml.write\
    .format("jdbc")\
    .option("url", url)\
    .option("dbtable","offres_emploi_ml")\
    .option("user", user)\
    .option("password",password)\
    .option("driver", driver)\
    .mode("append")\
    .save()

# %%
print("--------------------------tout esst carree-----------------------------")


spark.stop()

del spark
print('la session spark est arretée et supprimée')
# Out:
# --------------------------tout esst carree-----------------------------
# la session spark est arretée et supprimée

# %%
# creation d'une session spark 

#spark = SparkSession.builder \
#    .appName("Traitement_depuis_hdfs") \
#    .master("yarn") \
#    .config("spark.hadoop.fs.defaultFS", "hdfs://namenode:8020") \
#    .config("spark.hadoop.yarn.resourcemanager.hostname", "resourcemanager") \
#    .getOrCreate()


#### -------------------------------------------- Notre script Spark ---------------------------------#####

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, explode, regexp_replace,  date_format,  when, udf, to_date
from pyspark.sql import functions as F 
from pyspark.sql.types import DateType
from datetime import datetime


try:
   spark.stop()
except:
     pass 

spark = SparkSession.builder\
        .appName('traitement_NLP').getOrCreate()

# version de la version de spark 
spark.version


# lecture de nos fichier hdfs 
df = spark.read.option("mergeSchema", "true").parquet("hdfs://namenode:8020/ben/dataLake/")
df.count()


df = df.dropDuplicates()
# compter les nombres de lignes qu'on a 
df.count()


# voir le schema ou les differents colonnes de nos données 
df.printSchema()

# Les nombres de differents poste et  entreprises existantes 
df.select("poste").distinct().count()


df.select("entreprise").distinct().count()

#----------------- *** Colonnes a nettoyer et organiser ***-----------------------#
# Apres un passage de select, exemple la colonne suivant '"entreprise"
df.select("entreprise").distinct().show(5, truncate=False)

###------------- traitement de chaque colonne -------------------------------- ###### 

# ---------------- pour la colonne formation 

df_formation = df.withColumn(
    "formation_clean",
    F.trim(
        F.regexp_replace(F.col("formation"), r"</li><li>", ", "))
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.regexp_replace(F.col("formation_clean"), r"</?li>", "")
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.regexp_replace(F.col("formation_clean"), r"[\n]", "")
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.regexp_replace(F.col("formation_clean"),r"</?strong>", "")
)

df_formation = df_formation.withColumn(
    "formation_clean",
    F.trim(F.regexp_replace(F.col("formation_clean"), r"<[^>]+>", ""))
)

df_formation.drop("formation")



#-------------- Pour la colonne niveau_etude--------------

df_etude = df_formation.withColumn(
    "niveau_etude_clean",
    split(col("niveau_etude"), r"\s*(?:,|&|et)\s*")
)

df_etude = df_etude.drop("niveau_etude")
df_etude = df_etude.drop("formation")


##------------ contract proposé ---------------------------
df_contract = df_etude.withColumn(
    "contract",
    split(col("contrat_propose"), r"\s*(?:,|&|et)\s*")
)

df_contract = df_contract.drop("contrat_propose")


### ------------- Pour la region 

df_region = df_contract.withColumn(
    "region_clean",
    F.trim(F.regexp_replace(F.col("region"), r"\s*(?:\n|\t)", ""))

)

df_region = df_region.drop("region")



# ----- experience 

df_experience = df_region.withColumn(
    "experience", 
    split(col("niveau_experience"), r"\s*(?:,|&|-)\s*")
)

df_experience = df_experience.drop("niveau_experience")


#---------- Traitement des competences 

df_competence = df_experience.withColumn(
    "competences",
    split(col("Competence"), r"\s*(-)\s*")
)

df_date_nettoyer = df_competence.withColumn(
    "date_convertie",
    regexp_replace(col("date_de_publication"), "Publié le ", "")
)



# Fonction pour convertir les deux formats des dates 
def parse_date(date_str):
    if date_str is None:
        return None
    try:
        # Format 1: "12.06.2025"
        if "." in date_str and len(date_str.split(".")) == 3:
            return datetime.strptime(date_str, "%d.%m.%Y").date()
        
        # Format 2: "6 avril 2026"
        else:
            mois_fr_to_en = {
                'janvier': 'January', 'février': 'February', 'mars': 'March',
                'avril': 'April', 'mai': 'May', 'juin': 'June',
                'juillet': 'July', 'août': 'August', 'septembre': 'September',
                'octobre': 'October', 'novembre': 'November', 'décembre': 'December'
            }
            parts = date_str.split()
            if len(parts) >= 3:
                jour = parts[0].zfill(2)
                mois_fr = parts[1]
                annee = parts[2]
                mois_en = mois_fr_to_en.get(mois_fr, mois_fr)
                return datetime.strptime(f"{jour} {mois_en} {annee}", "%d %B %Y").date()
    except:
        return None
    return None

# Appliquer la conversion
parse_date_udf = udf(parse_date, DateType())
df_date_formatee = df_date_nettoyer.withColumn(
    "date_typee", 
    parse_date_udf(col("date_convertie"))
)


# Vérifier
df_date_formatee.select("date_de_publication","date_convertie", "date_typee").show(10, truncate=False)

###---------------------------------------------------------------------------------#######""
#------------------------------------------------------------------------------------#
# Creation de la premiere dataset qui contient toutes les données 

df_clean = df_date_formatee.drop("Competence")
df_clean = df_clean.drop("date_convertie","date_de_publication")


df_clean.show(5, truncate=False)


#### ---------------- Creation du dataSet normale -------------------------###


##########___-------Mise en forme----------__________________________###
df_propres = df_clean.select("entreprise", "poste", col("competences").alias("competence"),
col("formation_clean").alias("formation"), col("niveau_etude_clean").alias("niveau_etude"),
col("contract").alias("contrat"), col("experience").alias("experience"),
col("region_clean").alias("region"), col("date_typee").alias("date_de_publication")
)


# Creation du deuxieme dataset pour le machine learning

df_ml = df_clean.select("entreprise", "poste", explode(col("competences")).alias("competence"),
col("formation_clean").alias("formation"), explode(col("niveau_etude_clean")).alias("niveau_etude"),
explode(col("contract")).alias("contrat"), explode(col("experience")).alias("experience"),
col("region_clean").alias("region"), col("date_typee").alias("date_de_publication")
)


print("dataset pour le machine learning et l'analyse analytique")
df_ml.show(10, truncate=False)




############----------------===============---------------------------===-----#######
### ---------------------- nos liens --------------------------------------------####
url = "jdbc:postgresql://postgres_warehouse:5432/datawarehouse"
user = "admin"
password = "admin_pwd"
driver = "org.postgresql.Driver"



df_propres.write\
    .format("jdbc")\
    .option("url", url)\
    .option("dbtable","offres_emploi")\
    .option("user", user)\
    .option("password",password)\
    .option("driver", driver)\
    .mode("append")\
    .save()


###---------------Creation du dataset ML --------------------------------####

df_ml.write\
    .format("jdbc")\
    .option("url", url)\
    .option("dbtable","offres_emploi_ml")\
    .option("user", user)\
    .option("password",password)\
    .option("driver", driver)\
    .mode("append")\
    .save()



print("--------------------------tout esst carree-----------------------------")


spark.stop()

del spark
print('la session spark est arretée et supprimée')
