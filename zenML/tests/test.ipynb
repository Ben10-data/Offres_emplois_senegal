# %%
from zenml.client import Client

# %%
from zenml.client import Client

artifact = Client().get_artifact_version("1f592d98-53ff-4567-be24-f01cdd6c34c1")
data = artifact.load()
data

# %%
from zenml.client import Client

artifact2 = Client().get_artifact_version("5e88bd11-6e03-451d-8552-42db5384086b")
data2 = artifact2.load()
data2

# %%
data2.recommend("Python java Machine Learning SQL DBT html postgresql\
   css\
   mongodb\
   mysql\
   javascript", "Dakar", 0
   )
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.63it/s]
# [{'poste': 'Stagiaire Développeur Web - Dakar',
#   'region': 'dakar',
#   'score': 0.6122,
#   'missing_skills': []},
#  {'poste': 'RUBY ON RAILS Developer (M/F)',
#   'region': 'dakar',
#   'score': 0.5699,
#   'missing_skills': ['jquery',
#    'on',
#    'jira',
#    'agile',
#    'ruby',
#    'docker',
#    'git',
#    'cvs',
#    'rails']},
#  {'poste': 'NODE.JS Developer (M/F)',
#   'region': 'dakar',
#   'score': 0.5439,
#   'missing_skills': ['react',
#    'xml',
#    'jquery',
#    'cvs',
#    'nosql',
#    'jira',
#    'rest',
#    'mvc',
#    'docker',
#    'json',
#    'less',
#    'git',
#    'bootstrap',
#    'css3',
#    'node',
#    'js',
#    'redis']},
#  {'poste': 'PYTHON Developer (M/F)',
#   'region': 'dakar',
#   'score': 0.5119,
#   'missing_skills': ['django', 'api', 'agile', 'scrum', 'tornado', 'cvs']},
#  {'poste': 'JAVASCRIPT Developer (M/F)',
#   'region': 'dakar',
#   'score': 0.5066,
# ...

# %% [markdown]
# ### Modele 1

# %%
from zenml.client import Client
from zenml.client import Client

artifact = Client().get_artifact_version("a74b31ea-1bd4-44fa-942a-b33179b42a6e")
model =  artifact.load()

print(model, model.encoder, model.vectorizer)
# Out:
# <src.steps.model1.TfidfJobModel object at 0x761e3a7817c0> OneHotEncoder() TfidfVectorizer(max_features=5000)

# %%
prediction = model.predict("python machine learning", "dakar")
print(prediction)
# Out:
# /home/ben/Bureau/Pre-production/Offres_emplois_senegal/.benv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
#
# Cyber Security Engineer (M/F)

# %% [markdown]
# ### Modele 2

# %%
from zenml.client import Client

client = Client()
print(client.active_stack)

# %%
import joblib
loaded_model = joblib.load("../src/model_sauvegarde/model_minibert.joblib")
loaded_model
loaded_model.recommend("Python java Machine Learning SQL DBT html postgresql\
   css\
   mongodb\
   mysql\
   javascript", "Dakar", 0
   )



# loaded_model = joblib.load("/app/model_sauvegarde/model_minibert.joblib")

# %%
modele1 = joblib.load("../model_tfi.joblib")

# %%
modele1.predict('JAva', "Dakar")
# Out:
# /home/ben/Bureau/Pre-production/Offres_emplois_senegal/.benv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# 'Lead Développeur Java JEE (H/F)'
